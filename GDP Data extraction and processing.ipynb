# %%
# !pip install pandas numpy 
# !pip install lxml

# %%
import numpy as np
import pandas as pd

# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %%
URL="https://web.archive.org/web/20230902185326/https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29"
tables = pd.read_html(URL)
df = tables[3]

df
# Out:
#     Country/Territory UN region IMF[1][13]            World Bank[14]  \
#     Country/Territory UN region   Estimate       Year       Estimate
# 0               World         —  105568776       2023      100562011
# 1       United States  Americas   26854599       2023       25462700
# 2               China      Asia   19373586  [n 1]2023       17963171
# 3               Japan      Asia    4409738       2023        4231141
# 4             Germany    Europe    4308854       2023        4072192
# ..                ...       ...        ...        ...            ...
# 209          Anguilla  Americas          —          —              —
# 210          Kiribati   Oceania        248       2023            223
# 211             Nauru   Oceania        151       2023            151
# 212        Montserrat  Americas          —          —              —
# 213            Tuvalu   Oceania         65       2023             60
#
#                United Nations[15]
# ...

# %%
# Replace the column headers with column numbers
df.columns = range(df.shape[1])
df
# Out:
#                  0         1          2          3          4          5  \
# 0            World         —  105568776       2023  100562011       2022
# 1    United States  Americas   26854599       2023   25462700       2022
# 2            China      Asia   19373586  [n 1]2023   17963171  [n 3]2022
# 3            Japan      Asia    4409738       2023    4231141       2022
# 4          Germany    Europe    4308854       2023    4072192       2022
# ..             ...       ...        ...        ...        ...        ...
# 209       Anguilla  Americas          —          —          —          —
# 210       Kiribati   Oceania        248       2023        223       2022
# 211          Nauru   Oceania        151       2023        151       2022
# 212     Montserrat  Americas          —          —          —          —
# 213         Tuvalu   Oceania         65       2023         60       2022
#
#             6          7
# 0    96698005       2021
# 1    23315081       2021
# ...

# %%
# Retain the Rows with index 1 to 10, indicating the top 10 economies of the world.
df = df.iloc[1:11,:]
df
# Out:
#                  0         1         2          3         4          5  \
# 1    United States  Americas  26854599       2023  25462700       2022
# 2            China      Asia  19373586  [n 1]2023  17963171  [n 3]2022
# 3            Japan      Asia   4409738       2023   4231141       2022
# 4          Germany    Europe   4308854       2023   4072192       2022
# 5            India      Asia   3736882       2023   3385090       2022
# 6   United Kingdom    Europe   3158938       2023   3070668       2022
# 7           France    Europe   2923489       2023   2782905       2022
# 8            Italy    Europe   2169745       2023   2010432       2022
# 9           Canada  Americas   2089672       2023   2139840       2022
# 10          Brazil  Americas   2081235       2023   1920096       2022
#
#            6          7
# 1   23315081       2021
# 2   17734131  [n 1]2021
# 3    4940878       2021
# 4    4259935       2021
# 5    3201471       2021
# 6    3131378       2021
# ...

# %%
# Retain columns with index 0 and 2 (name of country and value of GDP quoted by IMF)
df = df[[0,2]]
df
# Out:
#                  0         2
# 1    United States  26854599
# 2            China  19373586
# 3            Japan   4409738
# 4          Germany   4308854
# 5            India   3736882
# 6   United Kingdom   3158938
# 7           France   2923489
# 8            Italy   2169745
# 9           Canada   2089672
# 10          Brazil   2081235

# %%
# Assign column names as "Country" and "GDP (Million USD)"
df.columns = ['Country','GDP (Million USD)']
df
# Out:
#            Country GDP (Million USD)
# 1    United States          26854599
# 2            China          19373586
# 3            Japan           4409738
# 4          Germany           4308854
# 5            India           3736882
# 6   United Kingdom           3158938
# 7           France           2923489
# 8            Italy           2169745
# 9           Canada           2089672
# 10          Brazil           2081235

# %%
# Change the data type of the 'GDP (Million USD)' column to integer. Use astype() method.
df['GDP (Million USD)'] = df['GDP (Million USD)'].astype(int)
df
# Out:
#            Country  GDP (Million USD)
# 1    United States           26854599
# 2            China           19373586
# 3            Japan            4409738
# 4          Germany            4308854
# 5            India            3736882
# 6   United Kingdom            3158938
# 7           France            2923489
# 8            Italy            2169745
# 9           Canada            2089672
# 10          Brazil            2081235

# %%
# Convert the GDP value in Million USD to Billion USD
df[['GDP (Million USD)']] = df[['GDP (Million USD)']]/1000
df
# Out:
#            Country  GDP (Million USD)
# 1    United States          26854.599
# 2            China          19373.586
# 3            Japan           4409.738
# 4          Germany           4308.854
# 5            India           3736.882
# 6   United Kingdom           3158.938
# 7           France           2923.489
# 8            Italy           2169.745
# 9           Canada           2089.672
# 10          Brazil           2081.235

# %%
# Use numpy.round() method to round the value to 2 decimal places.
df[['GDP (Million USD)']] = np.round(df[['GDP (Million USD)']], 2)
df
# Out:
#            Country  GDP (Million USD)
# 1    United States           26854.60
# 2            China           19373.59
# 3            Japan            4409.74
# 4          Germany            4308.85
# 5            India            3736.88
# 6   United Kingdom            3158.94
# 7           France            2923.49
# 8            Italy            2169.74
# 9           Canada            2089.67
# 10          Brazil            2081.24

# %%
# Rename the column header from 'GDP (Million USD)' to 'GDP (Billion USD)'

# df.rename() method in Pandas returns a new DataFrame with the renamed columns. 
#             It does not modify the original DataFrame df in place by default.
# To make the change permanent, you need to either:
# 1- Assign the result back to df
# df = df.rename(columns={'GDP (Million USD)': 'GDP (Billion USD)'})
# df
#
# Or 
# 2- Use the inplace=True argument:
# df.rename(columns={'GDP (Million USD)': 'GDP (Billion USD)'}, inplace=True)
# df

df.rename(columns={'GDP (Million USD)': 'GDP (Billion USD)'}, inplace=True)
df
# Out:
#            Country  GDP (Billion USD)
# 1    United States           26854.60
# 2            China           19373.59
# 3            Japan            4409.74
# 4          Germany            4308.85
# 5            India            3736.88
# 6   United Kingdom            3158.94
# 7           France            2923.49
# 8            Italy            2169.74
# 9           Canada            2089.67
# 10          Brazil            2081.24

# %%
# Load the DataFrame to the CSV file named "Largest_economies.csv"
df.to_csv('./Largest_economies.csv')
